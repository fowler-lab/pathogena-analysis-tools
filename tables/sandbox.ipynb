# %%
import pandas

# %%
genomes = pandas.read_parquet('genomes.parquet')
print(f"There are {len(genomes)} genomes in the dataset.")
genomes[:3]
# Out:
# There are 77 genomes in the dataset.
#                                                 species  n_lineages   lineage  \
# uniqueid
# site.ENA.subj.SAMN03648077.lab.1.iso.1  M. tuberculosis           1  lineage4
# site.ENA.subj.SAMEA1403592.lab.1.iso.1  M. tuberculosis           1  lineage4
# site.ENA.subj.SAMN07766210.lab.1.iso.1  M. tuberculosis           1  lineage1
#
#                                             sublineage  mycobacterial_reads  \
# uniqueid
# site.ENA.subj.SAMN03648077.lab.1.iso.1  lineage4.6.1.2              4820884
# site.ENA.subj.SAMEA1403592.lab.1.iso.1    lineage4.2.1              3290666
# site.ENA.subj.SAMN07766210.lab.1.iso.1    lineage1.2.1              3667176
#
#                                         tb_reads  tb_coverage  tb_depth  \
# uniqueid
# site.ENA.subj.SAMN03648077.lab.1.iso.1   4695252      99.7035  103.2910
# site.ENA.subj.SAMEA1403592.lab.1.iso.1   3213994      99.8773   69.0550
# site.ENA.subj.SAMN07766210.lab.1.iso.1   3585232      99.7362   99.2324
#
#                                         mykrobe_lineage_coverage  \
# uniqueid
# site.ENA.subj.SAMN03648077.lab.1.iso.1                     100.0
# site.ENA.subj.SAMEA1403592.lab.1.iso.1                     100.0
# site.ENA.subj.SAMN07766210.lab.1.iso.1                       0.0
#
#                                         mykrobe_lineage_depth     antibiogram  \
# uniqueid
# site.ENA.subj.SAMN03648077.lab.1.iso.1                   90.0  RRSSSSUSSSRSUS
# site.ENA.subj.SAMEA1403592.lab.1.iso.1                   64.0  SSSSSSSSSSSSSS
# site.ENA.subj.SAMN07766210.lab.1.iso.1                    0.0  SSSSSSUSSSRSUS
#
#                                        pipeline_build
# uniqueid
# site.ENA.subj.SAMN03648077.lab.1.iso.1        149a518
# site.ENA.subj.SAMEA1403592.lab.1.iso.1        149a518
# site.ENA.subj.SAMN07766210.lab.1.iso.1        149a518

# %%
genomes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, site.ENA.subj.SAMN03648077.lab.1.iso.1 to site.ENA.subj.SAMEA1016056.lab.1.iso.1
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   species                   77 non-null     object
#  1   n_lineages                77 non-null     int64
#  2   lineage                   77 non-null     category
#  3   sublineage                77 non-null     category
#  4   mycobacterial_reads       77 non-null     int64
#  5   tb_reads                  77 non-null     int64
#  6   tb_coverage               77 non-null     float64
#  7   tb_depth                  77 non-null     float64
#  8   mykrobe_lineage_coverage  76 non-null     float64
#  9   mykrobe_lineage_depth     76 non-null     float64
#  10  antibiogram               77 non-null     category
#  11  pipeline_build            77 non-null     category
# dtypes: category(4), float64(4), int64(3), object(1)
# memory usage: 8.7+ KB

# %%
master = pandas.read_parquet('ENA_LOOKUP.parquet')
master[:3]
# Out:
#                                          study_accession sample_accession  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1      PRJEB23245   SAMEA104362043
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1      PRJEB23245   SAMEA104362044
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1      PRJEB23245   SAMEA104362045
#
#                                          run_accession  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1    ERR2184202
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1    ERR2184203
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1    ERR2184204
#
#                                                                                 center_name  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1  University of Oxford;Nuffield Department of Me...
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1  University of Oxford;Nuffield Department of Me...
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1  University of Oxford;Nuffield Department of Me...
#
#                                          country location first_public  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1    None     None   2019-06-12
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1    None     None   2019-06-12
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1    None     None   2019-06-12
#
#                                                                                   fastq_ftp  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR218/002/ERR218...
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR218/003/ERR218...
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR218/004/ERR218...
#
#                                                                                   fastq_md5  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1  612e42126398723aa1ee84dd1e06feec;349b4db6faead...
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1  469becc8e8fb3961bde32b5352858190;b13aca3a9005c...
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1  d97d6b0ae3ba59f6bfa19e304ac8d94f;022a232fe2db3...
#
#                                                  fastq_bytes  has_effects  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1  79400918;105468452        False
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1   67987132;86536083        False
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1   57530779;72231695        False
#
#                                           has_variants  has_mutations  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1         False          False
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1         False          False
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1         False          False
#
#                                           has_predictions  has_main_report  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1            False            False
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1            False            False
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1            False            False
#
#                                           in_mapping_file
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1            False
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1            False
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1            False

# %%
master.index.nunique()
# Out:
# 45420

# %%
mutations = pandas.read_parquet('mutations.parquet')
mutations.reset_index(inplace=True)
mutations[:3]
# Out:
#                                  uniqueid  gene mutation  ref  alt  \
# 0  site.ENA.subj.SAMN07766182.lab.1.iso.1   PE1    L485L  ctg  ttg
# 1  site.ENA.subj.SAMN07766182.lab.1.iso.1  PE14    A106A  gca  gcc
# 2  site.ENA.subj.SAMN07766182.lab.1.iso.1  PE16     A96A  gcg  gct
#
#    nucleotide_number  nucleotide_index  gene_position  codes_protein  \
# 0                NaN               NaN          485.0           True
# 1                NaN               NaN          106.0           True
# 2                NaN               NaN           96.0           True
#
#    indel_length indel_nucleotides  amino_acid_number amino_acid_sequence  \
# 0           NaN              None              485.0                   L
# 1           NaN              None              106.0                   A
# 2           NaN              None               96.0                   A
#
#    number_nucleotide_changes  is_null  is_minor minor_mutation  minor_reads
# 0                        1.0    False     False            NaN          NaN
# 1                        1.0    False     False            NaN          NaN
# 2                        1.0    False     False            NaN          NaN

# %%
mutations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116853 entries, 0 to 116852
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   uniqueid                   116853 non-null  object
#  1   gene                       116853 non-null  category
#  2   mutation                   116853 non-null  object
#  3   ref                        106043 non-null  category
#  4   alt                        106043 non-null  category
#  5   nucleotide_number          9017 non-null    float64
#  6   nucleotide_index           9017 non-null    float64
#  7   gene_position              116670 non-null  float64
#  8   codes_protein              116853 non-null  bool
#  9   indel_length               10598 non-null   float64
#  10  indel_nucleotides          10598 non-null   object
#  11  amino_acid_number          99221 non-null   float64
#  12  amino_acid_sequence        99221 non-null   category
#  13  number_nucleotide_changes  106043 non-null  float64
#  14  is_null                    116853 non-null  bool
#  15  is_minor                   116853 non-null  bool
#  16  minor_mutation             17453 non-null   category
#  17  minor_reads                17453 non-null   float64
# dtypes: bool(3), category(5), float64(7), object(3)
# memory usage: 10.6+ MB

# %%
mutations.mutation.value_counts()
# Out:
# mutation
# a-3g     155
# A111A    146
# L63L     144
# A72A     125
# A18A     122
#         ...
# L3M        1
# E366K      1
# A208V      1
# A537V      1
# V145V      1
# Name: count, Length: 22039, dtype: int64

# %%
mutations[mutations.is_minor]
# Out:
#                                         uniqueid       gene mutation  ref  \
# 9         site.ENA.subj.SAMN07766182.lab.1.iso.1       PE35     E99Z  gaa
# 21        site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS10    A180Z  gcc
# 22        site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS10    R225Z  agg
# 23        site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS10    G509Z  ggc
# 24        site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS10    A518Z  gcc
# ...                                          ...        ...      ...  ...
# 116370  site.ENA.subj.SAMEA104394448.lab.1.iso.1      mmpL5    T794Z  acc
# 116543  site.ENA.subj.SAMEA104394448.lab.1.iso.1      pks12   A3586Z  gcg
# 116544  site.ENA.subj.SAMEA104394448.lab.1.iso.1      pks12   G3602Z  ggt
# 116579  site.ENA.subj.SAMEA104394448.lab.1.iso.1       plcC     Y97Z  tac
# 116713  site.ENA.subj.SAMEA104394448.lab.1.iso.1       rpfA    A209Z  gca
#
#         alt  nucleotide_number  nucleotide_index  gene_position  \
# 9       taa                NaN               NaN           99.0
# 21      gcg                NaN               NaN          180.0
# 22      ggg                NaN               NaN          225.0
# 23      ggt                NaN               NaN          509.0
# 24      ggc                NaN               NaN          518.0
# ...     ...                ...               ...            ...
# 116370  atc                NaN               NaN          794.0
# 116543  gtg                NaN               NaN         3586.0
# 116544  ggc                NaN               NaN         3602.0
# 116579  aac                NaN               NaN           97.0
# 116713  gcg                NaN               NaN          209.0
#
#         codes_protein  indel_length indel_nucleotides  amino_acid_number  \
# 9                True           NaN              None               99.0
# 21               True           NaN              None              180.0
# 22               True           NaN              None              225.0
# 23               True           NaN              None              509.0
# 24               True           NaN              None              518.0
# ...               ...           ...               ...                ...
# 116370           True           NaN              None              794.0
# 116543           True           NaN              None             3586.0
# 116544           True           NaN              None             3602.0
# 116579           True           NaN              None               97.0
# 116713           True           NaN              None              209.0
#
#        amino_acid_sequence  number_nucleotide_changes  is_null  is_minor  \
# 9                        !                        1.0    False      True
# 21                       A                        1.0    False      True
# 22                       G                        1.0    False      True
# 23                       G                        1.0    False      True
# 24                       G                        1.0    False      True
# ...                    ...                        ...      ...       ...
# 116370                   I                        1.0    False      True
# 116543                   V                        1.0    False      True
# 116544                   G                        1.0    False      True
# 116579                   N                        1.0    False      True
# 116713                   A                        1.0    False      True
#
#        minor_mutation  minor_reads
# 9                E99!         15.0
# 21              A180A         10.0
# 22              R225G         22.0
# 23              G509G          3.0
# 24              A518G          4.0
# ...               ...          ...
# 116370          T794I          6.0
# 116543         A3586V         46.0
# 116544         G3602G         60.0
# 116579           Y97N          3.0
# 116713          A209A          4.0
#
# [17453 rows x 18 columns]

# %%
variants = pandas.read_parquet('variants.parquet')
variants.reset_index(inplace=True)
variants[:3]
# Out:
#                                  uniqueid  gene  variant  gene_position  \
# 0  site.ENA.subj.SAMN01908825.lab.1.iso.1  dnaN  1977a>g          -75.0
# 1  site.ENA.subj.SAMN01908825.lab.1.iso.1  recF  4013t>c          245.0
# 2  site.ENA.subj.SAMN01908825.lab.1.iso.1  gyrA  7362g>c           21.0
#
#    codon_idx  nucleotide_index  indel_length indel_nucleotides  \
# 0        NaN              1977             0              None
# 1        1.0              4013             0              None
# 2        0.0              7362             0              None
#
#                                         vcf_evidence  vcf_idx  is_null  \
# 0  {"DP": 115, "GT": [1, 1], "GT_CONF": 738.27, "...      1.0    False
# 1  {"ALLELE_DP": [0, 110], "COV": [0, 110], "DP":...      1.0    False
# 2  {"ALLELE_DP": [0, 127], "GT": [1, 1], "DP": 12...      1.0    False
#
#    is_minor minor_variant  minor_reads  coverage
# 0     False          None            0       115
# 1     False          None            0       110
# 2     False          None            0       127

# %%
variants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120882 entries, 0 to 120881
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   uniqueid           120882 non-null  object
#  1   gene               120882 non-null  category
#  2   variant            120882 non-null  object
#  3   gene_position      120881 non-null  float64
#  4   codon_idx          112041 non-null  float64
#  5   nucleotide_index   120882 non-null  int64
#  6   indel_length       120882 non-null  int64
#  7   indel_nucleotides  10645 non-null   object
#  8   vcf_evidence       120882 non-null  object
#  9   vcf_idx            117794 non-null  float64
#  10  is_null            120882 non-null  bool
#  11  is_minor           120882 non-null  bool
#  12  minor_variant      18354 non-null   object
#  13  minor_reads        120882 non-null  int64
#  14  coverage           120882 non-null  int64
# dtypes: bool(2), category(1), float64(3), int64(4), object(5)
# memory usage: 11.7+ MB

# %%
MUTATIONS = pandas.read_pickle('/Users/fowler/files/cryptic/cryptic-tables-v2.1.2/MUTATIONS.pkl.gz')
MUTATIONS.reset_index(inplace=True)
MUTATIONS[:3]
# Out:
#                                UNIQUEID     GENE MUTATION  REF  ALT  \
# 0  site.01.subj.DR0682.lab.DR0682.iso.1   fadD34     S16W  tcg  tgg
# 1  site.01.subj.DR0682.lab.DR0682.iso.1   fadD34     T26S  act  tct
# 2  site.01.subj.DR0682.lab.DR0682.iso.1  Rv1231c     L60L  ctg  ctc
#
#    NUCLEOTIDE_NUMBER  NUCLEOTIDE_INDEX  GENE_POSITION  CODES_PROTEIN  \
# 0                NaN               NaN           16.0           True
# 1                NaN               NaN           26.0           True
# 2                NaN               NaN           60.0           True
#
#    INDEL_LENGTH INDEL_NUCLEOTIDES  AMINO_ACID_NUMBER AMINO_ACID_SEQUENCE  \
# 0           NaN               nan               16.0                   W
# 1           NaN               nan               26.0                   S
# 2           NaN               nan               60.0                   L
#
#    NUMBER_NUCLEOTIDE_CHANGES  IS_MINOR_ALLELE MINOR_MUTATION  FRS
# 0                        1.0            False           None  NaN
# 1                        1.0            False           None  NaN
# 2                        1.0            False           None  NaN

# %%
VARIANTS = pandas.read_pickle('/Users/fowler/files/cryptic/cryptic-tables-v2.1.2/VARIANTS.pkl.gz')
VARIANTS.reset_index(inplace=True)
VARIANTS[:3]
# Out:
#                                UNIQUEID  VARIANT  GENE  GENE_POSITION  \
# 0  site.01.subj.DR0682.lab.DR0682.iso.1  1977a>g  dnaN          -75.0
# 1  site.01.subj.DR0682.lab.DR0682.iso.1  4013t>c  recF          245.0
# 2  site.01.subj.DR0682.lab.DR0682.iso.1  7362g>c  gyrA           21.0
#
#    CODON_IDX  NUCLEOTIDE_INDEX  INDEL_LENGTH INDEL_NUCLEOTIDES  \
# 0        NaN            1977.0           0.0               nan
# 1        1.0            4013.0           0.0               nan
# 2        0.0            7362.0           0.0               nan
#
#                                         VCF_EVIDENCE  VCF_IDX  \
# 0  {"GT": [1, 1], "DP": 45.0, "ALLELE_DP": [0.0, ...      1.0
# 1  {"GT": [1, 1], "DP": 103.0, "ALLELE_DP": [0.0,...      1.0
# 2  {"GT": [1, 1], "DP": 61.0, "ALLELE_DP": [0.0, ...      1.0
#
#    IS_MINOR_ALLELE MINOR_VARIANT  FRS
# 0            False          None  NaN
# 1            False          None  NaN
# 2            False          None  NaN

# %%
MUTATIONS.columns
# Out:
# Index(['UNIQUEID', 'GENE', 'MUTATION', 'REF', 'ALT', 'NUCLEOTIDE_NUMBER',
#        'NUCLEOTIDE_INDEX', 'GENE_POSITION', 'CODES_PROTEIN', 'INDEL_LENGTH',
#        'INDEL_NUCLEOTIDES', 'AMINO_ACID_NUMBER', 'AMINO_ACID_SEQUENCE',
#        'NUMBER_NUCLEOTIDE_CHANGES', 'IS_MINOR_ALLELE', 'MINOR_MUTATION',
#        'FRS'],
#       dtype='object')

# %%
MUTATIONS[MUTATIONS.IS_MINOR_ALLELE & (MUTATIONS.INDEL_LENGTH>0)]
# Out:
#                                                    UNIQUEID    GENE  \
# 121146                 site.01.subj.DR0623.lab.DR0623.iso.1  Rv0678
# 121148                 site.01.subj.DR0623.lab.DR0623.iso.1  Rv0678
# 144304                 site.01.subj.DR0144.lab.DR0144.iso.1     gid
# 207468                     site.16.subj.001.lab.10398.iso.1    pncA
# 210143                     site.16.subj.001.lab.15323.iso.1    inhA
# ...                                                     ...     ...
# 57561611  site.07.subj.C32A080B-63AC-4427-9257-073281798...     rrs
# 57561612  site.07.subj.C32A080B-63AC-4427-9257-073281798...     rrs
# 57561616  site.07.subj.C32A080B-63AC-4427-9257-073281798...     rrs
# 57561618  site.07.subj.C32A080B-63AC-4427-9257-073281798...     rrs
# 57561620  site.07.subj.C32A080B-63AC-4427-9257-073281798...     rrs
#
#                 MUTATION  REF  ALT  NUCLEOTIDE_NUMBER  NUCLEOTIDE_INDEX  \
# 121146    135_minorindel  nan  nan              135.0          779124.0
# 121148    192_minorindel  nan  nan              192.0          779181.0
# 144304    352_minorindel  nan  nan              352.0         4407851.0
# 207468    457_minorindel  nan  nan              457.0         2288785.0
# 210143    -10_minorindel  nan  nan              -10.0         1674192.0
# ...                  ...  ...  ...                ...               ...
# 57561611  459_minorindel  nan  nan              459.0         1472304.0
# 57561612  461_minorindel  nan  nan              461.0         1472306.0
# 57561616  483_minorindel  nan  nan              483.0         1472328.0
# 57561618  589_minorindel  nan  nan              589.0         1472434.0
# 57561620  601_minorindel  nan  nan              601.0         1472446.0
#
#           GENE_POSITION  CODES_PROTEIN  INDEL_LENGTH INDEL_NUCLEOTIDES  \
# 121146            135.0           True           5.0             tgtga
# 121148            192.0           True           1.0                 g
# 144304            352.0           True           1.0                 g
# 207468            457.0           True           1.0                 c
# 210143            -10.0          False          11.0       taaggatattg
# ...                 ...            ...           ...               ...
# 57561611          459.0          False           3.0               aca
# 57561612          461.0          False           2.0                gg
# 57561616          483.0          False           2.0                gt
# 57561618          589.0          False           1.0                 c
# 57561620          601.0          False           1.0                 c
#
#           AMINO_ACID_NUMBER AMINO_ACID_SEQUENCE  NUMBER_NUCLEOTIDE_CHANGES  \
# 121146                  NaN                 nan                        0.0
# 121148                  NaN                 nan                        0.0
# 144304                  NaN                 nan                        0.0
# 207468                  NaN                 nan                        0.0
# 210143                  NaN                 nan                        0.0
# ...                     ...                 ...                        ...
# 57561611                NaN                 nan                        0.0
# 57561612                NaN                 nan                        0.0
# 57561616                NaN                 nan                        0.0
# 57561618                NaN                 nan                        0.0
# 57561620                NaN                 nan                        0.0
#
#           IS_MINOR_ALLELE       MINOR_MUTATION    FRS
# 121146               True        135_ins_tgtga  0.310
# 121148               True            192_ins_g  0.218
# 144304               True            352_ins_g  0.250
# 207468               True            457_ins_c  0.851
# 210143               True  -10_ins_taaggatattg  0.663
# ...                   ...                  ...    ...
# 57561611             True          459_ins_aca  0.727
# 57561612             True           461_ins_gg  0.714
# 57561616             True           483_ins_gt  0.632
# 57561618             True            589_ins_c  0.400
# 57561620             True            601_ins_c  0.429
#
# [10322 rows x 17 columns]

# %%
MUTATIONS[MUTATIONS.MUTATION.str[-1]=='x']
# Out:
# Empty DataFrame
# Columns: [UNIQUEID, GENE, MUTATION, REF, ALT, NUCLEOTIDE_NUMBER, NUCLEOTIDE_INDEX, GENE_POSITION, CODES_PROTEIN, INDEL_LENGTH, INDEL_NUCLEOTIDES, AMINO_ACID_NUMBER, AMINO_ACID_SEQUENCE, NUMBER_NUCLEOTIDE_CHANGES, IS_MINOR_ALLELE, MINOR_MUTATION, FRS]
# Index: []

# %%
mutations[mutations.mutation.str.contains('X')][:10]
# Out:
#                                    uniqueid       gene mutation  ref  alt  \
# 16   site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS10    A511X  gcc  gxc
# 17   site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS10    A513X  gcg  gxg
# 18   site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS10    L515X  ttg  ttx
# 19   site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS10    A517X  gcc  xcc
# 62   site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS23    G443X  ggc  ggx
# 112  site.ENA.subj.SAMN07766182.lab.1.iso.1   PE_PGRS4    !838X  taa  tax
# 128  site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS47    S271X  agc  xgc
# 144  site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS54    G594X  ggg  ggx
# 162  site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS56    D177X  gat  gxt
# 163  site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS57    G265X  ggc  ggx
#
#      nucleotide_number  nucleotide_index  gene_position  codes_protein  \
# 16                 NaN               NaN          511.0           True
# 17                 NaN               NaN          513.0           True
# 18                 NaN               NaN          515.0           True
# 19                 NaN               NaN          517.0           True
# 62                 NaN               NaN          443.0           True
# 112                NaN               NaN          838.0           True
# 128                NaN               NaN          271.0           True
# 144                NaN               NaN          594.0           True
# 162                NaN               NaN          177.0           True
# 163                NaN               NaN          265.0           True
#
#      indel_length indel_nucleotides  amino_acid_number amino_acid_sequence  \
# 16            NaN              None              511.0                   X
# 17            NaN              None              513.0                   X
# 18            NaN              None              515.0                   X
# 19            NaN              None              517.0                   X
# 62            NaN              None              443.0                   X
# 112           NaN              None              838.0                   X
# 128           NaN              None              271.0                   X
# 144           NaN              None              594.0                   X
# 162           NaN              None              177.0                   X
# 163           NaN              None              265.0                   X
#
#      number_nucleotide_changes  is_null  is_minor minor_mutation  minor_reads
# 16                         1.0     True     False            NaN          NaN
# 17                         1.0     True     False            NaN          NaN
# 18                         1.0     True     False            NaN          NaN
# 19                         1.0     True     False            NaN          NaN
# 62                         1.0     True     False            NaN          NaN
# 112                        1.0     True     False            NaN          NaN
# 128                        1.0     True     False            NaN          NaN
# 144                        1.0     True     False            NaN          NaN
# 162                        1.0     True     False            NaN          NaN
# 163                        1.0     True     False            NaN          NaN

# %%
mutations[mutations.mutation.str.contains(':')] # & (mutations.indel_length==0)]
# Out:
#                                       uniqueid       gene   mutation  ref  \
# 9       site.ENA.subj.SAMN07766182.lab.1.iso.1       PE35    E99!:15  gaa
# 21      site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS10   A180A:10  gcc
# 22      site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS10   R225G:22  agg
# 23      site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS10    G509G:3  ggc
# 24      site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS10    A518G:4  gcc
# ...                                        ...        ...        ...  ...
# 2511  site.ENA.subj.SAMEA104394448.lab.1.iso.1      mmpL5    T794I:6  acc
# 2684  site.ENA.subj.SAMEA104394448.lab.1.iso.1      pks12  A3586V:46  gcg
# 2685  site.ENA.subj.SAMEA104394448.lab.1.iso.1      pks12  G3602G:60  ggt
# 2720  site.ENA.subj.SAMEA104394448.lab.1.iso.1       plcC     Y97N:3  tac
# 2854  site.ENA.subj.SAMEA104394448.lab.1.iso.1       rpfA    A209A:4  gca
#
#       alt  nucleotide_number  nucleotide_index  gene_position  codes_protein  \
# 9     taa                NaN               NaN           99.0           True
# 21    gcg                NaN               NaN          180.0           True
# 22    ggg                NaN               NaN          225.0           True
# 23    ggt                NaN               NaN          509.0           True
# 24    ggc                NaN               NaN          518.0           True
# ...   ...                ...               ...            ...            ...
# 2511  atc                NaN               NaN          794.0           True
# 2684  gtg                NaN               NaN         3586.0           True
# 2685  ggc                NaN               NaN         3602.0           True
# 2720  aac                NaN               NaN           97.0           True
# 2854  gcg                NaN               NaN          209.0           True
#
#       indel_length indel_nucleotides  amino_acid_number amino_acid_sequence  \
# 9              NaN              None               99.0                   !
# 21             NaN              None              180.0                   A
# 22             NaN              None              225.0                   G
# 23             NaN              None              509.0                   G
# 24             NaN              None              518.0                   G
# ...            ...               ...                ...                 ...
# 2511           NaN              None              794.0                   I
# 2684           NaN              None             3586.0                   V
# 2685           NaN              None             3602.0                   G
# 2720           NaN              None               97.0                   N
# 2854           NaN              None              209.0                   A
#
#       number_nucleotide_changes
# 9                           1.0
# 21                          1.0
# 22                          1.0
# 23                          1.0
# 24                          1.0
# ...                         ...
# 2511                        1.0
# 2684                        1.0
# 2685                        1.0
# 2720                        1.0
# 2854                        1.0
#
# [17453 rows x 14 columns]

# %% [markdown]
# mutation -> mutation, is_null, is_minor_allele, minor_mutation, minor_reads
#
# `1241_ins_cgccggcgg:10` parsed to `1241_minorindel`, `False`, `True`, `1241_ins_cgccggcgg`, `10`
#
# `E99!:15` parsed to `E99Z`, `False`, `True`, `E99!`, `15`
#
# `g-57x` parsed to `g-57x`, `True`, `False`, None, None
#
# `A511X` parsed to `g-A511X`, `True`, `False`, None, None

# %%
mutations = pandas.read_parquet('mutations.parquet')
mutations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 116853 entries, ('site.ENA.subj.SAMN07766182.lab.1.iso.1', 'PE1', 'L485L') to ('site.ENA.subj.SAMEA104394448.lab.1.iso.1', 'zwf1', 'A79V')
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ref                        106043 non-null  category
#  1   alt                        106043 non-null  category
#  2   nucleotide_number          9017 non-null    float64
#  3   nucleotide_index           9017 non-null    float64
#  4   gene_position              116670 non-null  float64
#  5   codes_protein              116853 non-null  bool
#  6   indel_length               10598 non-null   float64
#  7   indel_nucleotides          10598 non-null   object
#  8   amino_acid_number          99221 non-null   float64
#  9   amino_acid_sequence        99221 non-null   category
#  10  number_nucleotide_changes  106043 non-null  float64
#  11  is_null                    116853 non-null  bool
#  12  is_minor                   116853 non-null  bool
#  13  minor_mutation             17453 non-null   category
#  14  minor_reads                17453 non-null   float64
# dtypes: bool(3), category(4), float64(7), object(1)
# memory usage: 9.8+ MB

# %%
mutations.is_minor.sum()
# Out:
# 17453

# %%
mutations.minor_reads.hist()
# Out:
# <Axes: >

# %%
mutations[mutations.is_minor & (mutations.indel_length.isna()) & (mutations.gene_position<0)]
# Out:
#                                       uniqueid       gene   mutation ref alt  \
# 38      site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS17  g-19c:118   g   c
# 45      site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS18    a-59g:3   a   g
# 88      site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS28    t-9a:39   t   a
# 89      site.ENA.subj.SAMN07766182.lab.1.iso.1  PE_PGRS28    a-6t:42   a   t
# 344     site.ENA.subj.SAMN07766182.lab.1.iso.1     Rv0072     c-8g:3   c   g
# ...                                        ...        ...        ...  ..  ..
# 2069  site.ENA.subj.SAMEA104394448.lab.1.iso.1       esxO   g-19a:66   g   a
# 2070  site.ENA.subj.SAMEA104394448.lab.1.iso.1       esxO   g-17t:68   g   t
# 2368  site.ENA.subj.SAMEA104394448.lab.1.iso.1       lpdA   g-75a:57   g   a
# 2369  site.ENA.subj.SAMEA104394448.lab.1.iso.1       lpdA   t-67c:50   t   c
# 2370  site.ENA.subj.SAMEA104394448.lab.1.iso.1       lpdA   g-65t:47   g   t
#
#       nucleotide_number  nucleotide_index  gene_position  codes_protein  \
# 38                -19.0         1094375.0          -19.0          False
# 45                -59.0         1096510.0          -59.0          False
# 88                 -9.0         1638238.0           -9.0          False
# 89                 -6.0         1638235.0           -6.0          False
# 344                -8.0           80616.0           -8.0          False
# ...                 ...               ...            ...            ...
# 2069              -19.0         2626191.0          -19.0          False
# 2070              -17.0         2626189.0          -17.0          False
# 2368              -75.0         3691013.0          -75.0          False
# 2369              -67.0         3691005.0          -67.0          False
# 2370              -65.0         3691003.0          -65.0          False
#
#       indel_length indel_nucleotides  amino_acid_number amino_acid_sequence  \
# 38             NaN              None                NaN                None
# 45             NaN              None                NaN                None
# 88             NaN              None                NaN                None
# 89             NaN              None                NaN                None
# 344            NaN              None                NaN                None
# ...            ...               ...                ...                 ...
# 2069           NaN              None                NaN                None
# 2070           NaN              None                NaN                None
# 2368           NaN              None                NaN                None
# 2369           NaN              None                NaN                None
# 2370           NaN              None                NaN                None
#
#       number_nucleotide_changes    mut  is_null  is_minor minor_mutation  \
# 38                          1.0  g-19z    False      True          g-19c
# 45                          1.0  a-59z    False      True          a-59g
# 88                          1.0   t-9z    False      True           t-9a
# 89                          1.0   a-6z    False      True           a-6t
# 344                         1.0   c-8z    False      True           c-8g
# ...                         ...    ...      ...       ...            ...
# 2069                        1.0  g-19z    False      True          g-19a
# 2070                        1.0  g-17z    False      True          g-17t
# 2368                        1.0  g-75z    False      True          g-75a
# 2369                        1.0  t-67z    False      True          t-67c
# 2370                        1.0  g-65z    False      True          g-65t
#
#       minor_reads
# 38          118.0
# 45            3.0
# 88           39.0
# 89           42.0
# 344           3.0
# ...           ...
# 2069         66.0
# 2070         68.0
# 2368         57.0
# 2369         50.0
# 2370         47.0
#
# [1316 rows x 19 columns]

# %%
VARIANTS[VARIANTS.IS_MINOR_ALLELE][:10]
# Out:
#                                    UNIQUEID     VARIANT  GENE  GENE_POSITION  \
# 7950   site.01.subj.DR0611.lab.DR0611.iso.1   760729a>z  rpoB          308.0
# 16139  site.01.subj.DR0600.lab.DR0600.iso.1  1472805c>z   rrs          960.0
# 34546  site.01.subj.DR0685.lab.DR0685.iso.1     7572t>z  gyrA           91.0
# 34547  site.01.subj.DR0685.lab.DR0685.iso.1     7582a>z  gyrA           94.0
# 41351  site.01.subj.DR0653.lab.DR0653.iso.1     8164c>z  gyrA          288.0
# 79166  site.01.subj.DR0589.lab.DR0589.iso.1   761100c>z  rpoB          432.0
# 79167  site.01.subj.DR0589.lab.DR0589.iso.1   761139c>z  rpoB          445.0
# 79168  site.01.subj.DR0589.lab.DR0589.iso.1   761161t>z  rpoB          452.0
# 93493  site.01.subj.DR0679.lab.DR0679.iso.1     7581g>z  gyrA           94.0
# 93494  site.01.subj.DR0679.lab.DR0679.iso.1     7582a>z  gyrA           94.0
#
#        CODON_IDX  NUCLEOTIDE_INDEX  INDEL_LENGTH INDEL_NUCLEOTIDES  \
# 7950         2.0          760729.0           0.0               nan
# 16139        NaN         1472805.0           0.0               nan
# 34546        1.0            7572.0           0.0               nan
# 34547        2.0            7582.0           0.0               nan
# 41351        2.0            8164.0           0.0               nan
# 79166        1.0          761100.0           0.0               nan
# 79167        1.0          761139.0           0.0               nan
# 79168        2.0          761161.0           0.0               nan
# 93493        1.0            7581.0           0.0               nan
# 93494        2.0            7582.0           0.0               nan
#
#                                             VCF_EVIDENCE  VCF_IDX  \
# 7950   {"GT": [1, 1], "DP": 77.0, "ALLELE_DP": [12.0,...      1.0
# 16139  {"GT": [0, 0], "DP": 47.0, "ALLELE_DP": [47.0,...      1.0
# 34546  {"GT": [0, 0], "DP": 36.0, "ALLELE_DP": [36.0,...      1.0
# 34547  {"GT": [1, 1], "DP": 39.0, "ALLELE_DP": [24.0,...      1.0
# 41351  {"GT": [1, 1], "DP": 121.0, "ALLELE_DP": [17.0...      1.0
# 79166  {"GT": [0, 0], "DP": 37.0, "ALLELE_DP": [37.0,...      1.0
# 79167  {"GT": [0, 0], "DP": 33.0, "ALLELE_DP": [33.0,...      1.0
# 79168  {"GT": [1, 1], "DP": 32.0, "ALLELE_DP": [18.0,...      1.0
# 93493  {"GT": [1, 1], "DP": 43.0, "ALLELE_DP": [25.0,...      1.0
# 93494  {"GT": [0, 0], "DP": 46.0, "ALLELE_DP": [46.0,...      1.0
#
#        IS_MINOR_ALLELE MINOR_VARIANT    FRS
# 7950              True     760729a>g  0.865
# 16139             True    1472805c>t  0.230
# 34546             True       7572t>c  0.357
# 34547             True       7582a>g  0.619
# 41351             True       8164c>a  0.877
# 79166             True     761100c>a  0.098
# 79167             True     761139c>a  0.283
# 79168             True     761161t>c  0.640
# 93493             True       7581g>a  0.632
# 93494             True       7582a>g  0.352

# %%
variants[variants.variant.str.contains('x')]
# Out:
#                                    uniqueid     variant       gene  \
# 45   site.ENA.subj.SAMN01908825.lab.1.iso.1    79571c>x     Rv0071
# 46   site.ENA.subj.SAMN01908825.lab.1.iso.1    80616c>x     Rv0072
# 144  site.ENA.subj.SAMN01908825.lab.1.iso.1   336560t>x   PE_PGRS4
# 145  site.ENA.subj.SAMN01908825.lab.1.iso.1   336590g>x   PE_PGRS4
# 146  site.ENA.subj.SAMN01908825.lab.1.iso.1   336592t>x   PE_PGRS4
# ..                                      ...         ...        ...
# 721  site.ENA.subj.SAMN07659930.lab.1.iso.1  3739498c>x  PE_PGRS50
# 762  site.ENA.subj.SAMN07659930.lab.1.iso.1  3934022t>x  PE_PGRS54
# 764  site.ENA.subj.SAMN07659930.lab.1.iso.1  3935950t>x  PE_PGRS54
# 765  site.ENA.subj.SAMN07659930.lab.1.iso.1  3946813a>x  PE_PGRS57
# 766  site.ENA.subj.SAMN07659930.lab.1.iso.1  3948612a>x  PE_PGRS57
#
#      gene_position  codon_idx  nucleotide_index  indel_length  \
# 45            29.0        1.0             79571             0
# 46            -8.0        NaN             80616             0
# 144          838.0        2.0            336560             0
# 145          828.0        2.0            336590             0
# 146          828.0        0.0            336592             0
# ..             ...        ...               ...           ...
# 721         1093.0        0.0           3739498             0
# 762         1006.0        2.0           3934022             0
# 764         1649.0        1.0           3935950             0
# 765          340.0        2.0           3946813             0
# 766          940.0        1.0           3948612             0
#
#     indel_nucleotides                                       vcf_evidence  \
# 45               None  {"ALLELE_DP": [0, 0], "FRS": ".", "GT_CONF_PER...
# 46               None  {"GT": [1, 1], "FRS": 1.0, "ALLELE_DP": [0, 1]...
# 144              None  {"GT": [0, 0], "COV_TOTAL": 1, "GT_CONF": 7.69...
# 145              None  {"FRS": 0.5, "GT": [0, 0], "GT_CONF": 0.0, "CO...
# 146              None  {"FRS": 0.5, "COV": [1, 1], "COV_TOTAL": 2, "G...
# ..                ...                                                ...
# 721              None  {"GT_CONF": 22.3, "ALLELE_DP": [0, 4], "DP": 4...
# 762              None  {"GT": [1, 1], "GT_CONF_PERCENTILE": 0.04, "CO...
# 764              None  {"COV_TOTAL": 0, "COV": [0, 0], "GT_CONF": 0.0...
# 765              None  {"GT_CONF_PERCENTILE": 0.04, "COV": [0, 1], "A...
# 766              None  {"COV_TOTAL": 3, "GT_CONF": 16.0, "DP": 2, "GT...
#
#      vcf_idx
# 45       NaN
# 46       1.0
# 144      0.0
# 145      0.0
# 146      0.0
# ..       ...
# 721      1.0
# 762      1.0
# 764      NaN
# 765      1.0
# 766      1.0
#
# [6083 rows x 10 columns]

# %% [markdown]
# variant -> variant, is_null, is_minor_allele, minor_varian, minor_reads, total_reads
#
# `7570c>t:76` parsed to `7570c>z`, `False`, `True`, `7570c>t`, 76, 110
#
# `24699_del_ccgcgttgctcggggtaa:41` parsed to `24699_minorindel`, `False`, `True`, `24699_del_ccgcgttgctcggggtaa`, 41, 47
#
# `338554t>x` parsed to `338554t>x`, `True`, `False`, None, None
#
#
# ```
# "{""COV"": [34, 76], ""COV_TOTAL"": 110, ""GT"": [1, 1], ""GT_CONF"": 261.86, ""GT_CONF_PERCENTILE"": 6.47, ""ALLELE_DP"": [34, 76], ""DP"": 76, ""FRS"": 0.6909, ""POS"": 7570, ""REF"": ""c"", ""ALTS"": [""t""]}"
# ```

# %%
variants.FRS.value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/84/9nb2gsqj4hlcxztvwf19wg680000gq/T/ipykernel_80391/2769733803.py in ?()
# ----> 1 variants.FRS.value_counts(dropna=False)
#
# ~/Library/Python/3.12/lib/python/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'FRS'

# %%
variants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120882 entries, 0 to 920
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   uniqueid           120882 non-null  object
#  1   variant            120882 non-null  object
#  2   gene               120882 non-null  object
#  3   gene_position      120881 non-null  float64
#  4   codon_idx          112041 non-null  float64
#  5   nucleotide_index   120882 non-null  int64
#  6   indel_length       120882 non-null  int64
#  7   indel_nucleotides  10645 non-null   object
#  8   vcf_evidence       120882 non-null  object
#  9   vcf_idx            117794 non-null  float64
#  10  var                120882 non-null  object
#  11  is_null            120882 non-null  bool
#  12  is_minor           120882 non-null  bool
#  13  minor_variant      18354 non-null   object
#  14  minor_reads        18354 non-null   object
#  15  coverage           120874 non-null  float64
#  16  FRS                120874 non-null  float64
# dtypes: bool(2), float64(5), int64(2), object(8)
# memory usage: 15.0+ MB

# %%
variants[variants.is_minor]
# Out:
#                                       uniqueid       gene             variant  \
# 1542    site.ENA.subj.SAMN01908825.lab.1.iso.1       gyrA             7570c>z
# 1543    site.ENA.subj.SAMN01908825.lab.1.iso.1       gyrA             7572t>z
# 1544    site.ENA.subj.SAMN01908825.lab.1.iso.1       fhaA    24699_minorindel
# 1545    site.ENA.subj.SAMN01908825.lab.1.iso.1       fhaA            24721g>z
# 1546    site.ENA.subj.SAMN01908825.lab.1.iso.1       fhaA            24722t>z
# ...                                        ...        ...                 ...
# 120877  site.ENA.subj.SAMN07659930.lab.1.iso.1  PE_PGRS57          3948649a>z
# 120878  site.ENA.subj.SAMN07659930.lab.1.iso.1  PE_PGRS58          4032006c>z
# 120879  site.ENA.subj.SAMN07659930.lab.1.iso.1  PE_PGRS59  4036926_minorindel
# 120880  site.ENA.subj.SAMN07659930.lab.1.iso.1       esxV          4060210t>z
# 120881  site.ENA.subj.SAMN07659930.lab.1.iso.1    Rv3802c          4263501t>z
#
#         gene_position  codon_idx  nucleotide_index  indel_length  \
# 1542             90.0        1.0              7570             0
# 1543             91.0        0.0              7572             0
# 1544            729.0        1.0             24699           -18
# 1545            242.0        0.0             24721             0
# 1546            241.0        2.0             24722             0
# ...               ...        ...               ...           ...
# 120877          952.0        2.0           3948649             0
# 120878          385.0        0.0           4032006             0
# 120879         1117.0        2.0           4036926            -9
# 120880           20.0        1.0           4060210             0
# 120881          289.0        0.0           4263501             0
#
#          indel_nucleotides                                       vcf_evidence  \
# 1542                  None  {"COV": [34, 76], "COV_TOTAL": 110, "GT": [1, ...
# 1543                  None  {"COV": [77, 35], "COV_TOTAL": 112, "GT_CONF":...
# 1544    ccgcgttgctcggggtaa  {"COV_TOTAL": 103, "COV": [10, 41], "GT": [1, ...
# 1545                  None  {"GT": [0, 0], "COV_TOTAL": 85, "FRS": 0.9176,...
# 1546                  None  {"FRS": 0.9195, "COV": [73, 7], "ALLELE_DP": [...
# ...                    ...                                                ...
# 120877                None  {"COV_TOTAL": 7, "FRS": 0.5714, "GT": [1, 1], ...
# 120878                None  {"COV": [0, 4], "GT": [1, 1], "DP": 4, "ALLELE...
# 120879           gccgcccgc  {"GT_CONF": 36.62, "COV_TOTAL": 4, "GT_CONF_PE...
# 120880                None  {"COV": [9, 61], "FRS": 0.8714, "GT_CONF_PERCE...
# 120881                None  {"GT_CONF": 311.55, "GT_CONF_PERCENTILE": 52.8...
#
#         vcf_idx  is_null  is_minor                 minor_variant  minor_reads  \
# 1542        1.0    False      True                       7570c>t           76
# 1543        1.0    False      True                       7572t>c           35
# 1544        1.0    False      True  24699_del_ccgcgttgctcggggtaa           41
# 1545        1.0    False      True                      24721g>c            7
# 1546        1.0    False      True                      24722t>c            7
# ...         ...      ...       ...                           ...          ...
# 120877      1.0    False      True                    3948649a>c            4
# 120878      1.0    False      True                    4032006c>g            4
# 120879      1.0    False      True         4036926_del_gccgcccgc            4
# 120880      1.0    False      True                    4060210t>a           61
# 120881      1.0    False      True                    4263501t>g            9
#
#         coverage
# 1542         110
# 1543         112
# 1544         103
# 1545          85
# 1546          87
# ...          ...
# 120877         7
# 120878         4
# 120879         4
# 120880        70
# 120881        68
#
# [18354 rows x 15 columns]

# %%
a = variants[(variants.uniqueid=='site.ENA.subj.SAMN01908825.lab.1.iso.1') & (variants.variant=='24699_minorindel')].vcf_evidence
json.loads(a.values[0])
# Out:
# {'COV_TOTAL': 103,
#  'COV': [10, 41],
#  'GT': [1, 1],
#  'FRS': 0.7767,
#  'GT_CONF_PERCENTILE': 6.47,
#  'ALLELE_DP': [25.7895, 80],
#  'GT_CONF': 261.66,
#  'DP': 80,
#  'POS': 24698,
#  'REF': 'gccgcgttgctcggggtaa',
#  'ALTS': ['g']}

# %%
lookup = pandas.read_csv('../data/ENA_EXTRACT.csv.gz')
lookup[:3]
# Out:
#                                    UNIQUEID study_accession sample_accession  \
# 0  site.05.subj.PTAN-0001.lab.TAN-001.iso.1      PRJEB23245   SAMEA104362043
# 1  site.05.subj.PTAN-0002.lab.TAN-004.iso.1      PRJEB23245   SAMEA104362044
# 2  site.05.subj.PTAN-0003.lab.TAN-006.iso.1      PRJEB23245   SAMEA104362045
#
#   run_accession                                        center_name country  \
# 0    ERR2184202  University of Oxford;Nuffield Department of Me...     NaN
# 1    ERR2184203  University of Oxford;Nuffield Department of Me...     NaN
# 2    ERR2184204  University of Oxford;Nuffield Department of Me...     NaN
#
#   location first_public                                          fastq_ftp  \
# 0      NaN   2019-06-12  ftp.sra.ebi.ac.uk/vol1/fastq/ERR218/002/ERR218...
# 1      NaN   2019-06-12  ftp.sra.ebi.ac.uk/vol1/fastq/ERR218/003/ERR218...
# 2      NaN   2019-06-12  ftp.sra.ebi.ac.uk/vol1/fastq/ERR218/004/ERR218...
#
#                                            fastq_md5         fastq_bytes
# 0  612e42126398723aa1ee84dd1e06feec;349b4db6faead...  79400918;105468452
# 1  469becc8e8fb3961bde32b5352858190;b13aca3a9005c...   67987132;86536083
# 2  d97d6b0ae3ba59f6bfa19e304ac8d94f;022a232fe2db3...   57530779;72231695

# %%
lookup["has_effects"] = False
lookup["has_variants"] = False
lookup["has_mutations"] = False
lookup["has_predictions"] = False
lookup["has_main_report"] = False
lookup["in_mapping_file"] = False
lookup.set_index("UNIQUEID", inplace=True)

# %%
lookup
# Out:
#                                          study_accession sample_accession  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1      PRJEB23245   SAMEA104362043
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1      PRJEB23245   SAMEA104362044
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1      PRJEB23245   SAMEA104362045
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1      PRJEB23245   SAMEA104362046
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1      PRJEB23245   SAMEA104362047
# ...                                                  ...              ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1       PRJNA428596     SAMN08629324
# site.ENA.subj.SAMN03647419.lab.1.iso.1       PRJNA282721     SAMN03647419
# site.ENA.subj.SAMN07766466.lab.1.iso.1       PRJNA413593     SAMN07766466
# site.ENA.subj.SAMN07659660.lab.1.iso.1       PRJNA401515     SAMN07659660
# site.ENA.subj.SAMN08708730.lab.1.iso.1       PRJNA428596     SAMN08708730
#
#                                          run_accession  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1    ERR2184202
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1    ERR2184203
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1    ERR2184204
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1    ERR2184205
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1    ERR2184206
# ...                                                ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1      SRR6797700
# site.ENA.subj.SAMN03647419.lab.1.iso.1      SRR2100246
# site.ENA.subj.SAMN07766466.lab.1.iso.1      SRR6152661
# site.ENA.subj.SAMN07659660.lab.1.iso.1      SRR6045415
# site.ENA.subj.SAMN08708730.lab.1.iso.1      SRR6832238
#
#                                                                                 center_name  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1  University of Oxford;Nuffield Department of Me...
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1  University of Oxford;Nuffield Department of Me...
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1  University of Oxford;Nuffield Department of Me...
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1  University of Oxford;Nuffield Department of Me...
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1  University of Oxford;Nuffield Department of Me...
# ...                                                                                     ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1                                           SUB3743403
# site.ENA.subj.SAMN03647419.lab.1.iso.1                                                  NaN
# site.ENA.subj.SAMN07766466.lab.1.iso.1                                                  NaN
# site.ENA.subj.SAMN07659660.lab.1.iso.1                                                  NaN
# site.ENA.subj.SAMN08708730.lab.1.iso.1                                           SUB3783172
#
#                                                            country  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1                       NaN
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1                       NaN
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1                       NaN
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1                       NaN
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1                       NaN
# ...                                                            ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1                     missing
# site.ENA.subj.SAMN03647419.lab.1.iso.1                     missing
# site.ENA.subj.SAMN07766466.lab.1.iso.1    Canada: British Columbia
# site.ENA.subj.SAMN07659660.lab.1.iso.1      United Kingdom: Oxford
# site.ENA.subj.SAMN08708730.lab.1.iso.1                     missing
#
#                                                  location first_public  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1              NaN   2019-06-12
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1              NaN   2019-06-12
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1              NaN   2019-06-12
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1              NaN   2019-06-12
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1              NaN   2019-06-12
# ...                                                   ...          ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1                NaN   2018-03-03
# site.ENA.subj.SAMN03647419.lab.1.iso.1                NaN   2015-11-03
# site.ENA.subj.SAMN07766466.lab.1.iso.1    49.15 N 123.7 W   2017-10-11
# site.ENA.subj.SAMN07659660.lab.1.iso.1                NaN   2017-12-01
# site.ENA.subj.SAMN08708730.lab.1.iso.1                NaN   2018-03-15
#
#                                                                                   fastq_ftp  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR218/002/ERR218...
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR218/003/ERR218...
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR218/004/ERR218...
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR218/005/ERR218...
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR218/006/ERR218...
# ...                                                                                     ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1    ftp.sra.ebi.ac.uk/vol1/fastq/SRR679/000/SRR679...
# site.ENA.subj.SAMN03647419.lab.1.iso.1    ftp.sra.ebi.ac.uk/vol1/fastq/SRR210/006/SRR210...
# site.ENA.subj.SAMN07766466.lab.1.iso.1    ftp.sra.ebi.ac.uk/vol1/fastq/SRR615/001/SRR615...
# site.ENA.subj.SAMN07659660.lab.1.iso.1    ftp.sra.ebi.ac.uk/vol1/fastq/SRR604/005/SRR604...
# site.ENA.subj.SAMN08708730.lab.1.iso.1    ftp.sra.ebi.ac.uk/vol1/fastq/SRR683/008/SRR683...
#
#                                                                                   fastq_md5  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1  612e42126398723aa1ee84dd1e06feec;349b4db6faead...
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1  469becc8e8fb3961bde32b5352858190;b13aca3a9005c...
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1  d97d6b0ae3ba59f6bfa19e304ac8d94f;022a232fe2db3...
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1  14c0e32a4b0bc1cf763a9d303c9e5ac0;45fc98858531f...
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1  13b208c2682162b7c43eff826e30a8c3;d38eebc5d32fd...
# ...                                                                                     ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1    bc924b9f084012d606433511bef0d18f;ca1f09a5d91f4...
# site.ENA.subj.SAMN03647419.lab.1.iso.1    91a4f700ec3b8a90edcb053dfefa13ad;105ff45492880...
# site.ENA.subj.SAMN07766466.lab.1.iso.1    6b6a27fbc68b9cdaa22a546c4378877a;29023ba0ad61b...
# site.ENA.subj.SAMN07659660.lab.1.iso.1    ed1a023558e8ba5e8f8365c4653c9ff6;a62e326689701...
# site.ENA.subj.SAMN08708730.lab.1.iso.1    3a728e1397b49458d4f709ec2d90fc5e;c8e136513d3e5...
#
#                                                          fastq_bytes  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1          79400918;105468452
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1           67987132;86536083
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1           57530779;72231695
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1           69943262;91063623
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1           69636113;88268311
# ...                                                              ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1    238157;159575999;160379837
# site.ENA.subj.SAMN03647419.lab.1.iso.1           177028172;177053910
# site.ENA.subj.SAMN07766466.lab.1.iso.1           194848851;192505193
# site.ENA.subj.SAMN07659660.lab.1.iso.1           132755503;156882560
# site.ENA.subj.SAMN08708730.lab.1.iso.1      440545;77020083;86536488
#
#                                           has_effects  has_variants  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1        False         False
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1        False         False
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1        False         False
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1        False         False
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1        False         False
# ...                                               ...           ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1          False         False
# site.ENA.subj.SAMN03647419.lab.1.iso.1          False         False
# site.ENA.subj.SAMN07766466.lab.1.iso.1          False         False
# site.ENA.subj.SAMN07659660.lab.1.iso.1          False         False
# site.ENA.subj.SAMN08708730.lab.1.iso.1          False         False
#
#                                           has_mutations  has_predictions  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1          False            False
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1          False            False
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1          False            False
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1          False            False
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1          False            False
# ...                                                 ...              ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1            False            False
# site.ENA.subj.SAMN03647419.lab.1.iso.1            False            False
# site.ENA.subj.SAMN07766466.lab.1.iso.1            False            False
# site.ENA.subj.SAMN07659660.lab.1.iso.1            False            False
# site.ENA.subj.SAMN08708730.lab.1.iso.1            False            False
#
#                                           has_main_report  in_mapping_file
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1            False            False
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1            False            False
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1            False            False
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1            False            False
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1            False            False
# ...                                                   ...              ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1              False            False
# site.ENA.subj.SAMN03647419.lab.1.iso.1              False            False
# site.ENA.subj.SAMN07766466.lab.1.iso.1              False            False
# site.ENA.subj.SAMN07659660.lab.1.iso.1              False            False
# site.ENA.subj.SAMN08708730.lab.1.iso.1              False            False
#
# [46800 rows x 16 columns]

# %%
lookup[lookup.index=='site.11.subj.MDR044.lab.SWE-33.iso.1']
# Out:
#                                      study_accession sample_accession  \
# UNIQUEID
# site.11.subj.MDR044.lab.SWE-33.iso.1      PRJEB76547   SAMEA115749410
# site.11.subj.MDR044.lab.SWE-33.iso.1      PRJEB76547   SAMEA115749411
# site.11.subj.MDR044.lab.SWE-33.iso.1      PRJEB76547   SAMEA115749412
# site.11.subj.MDR044.lab.SWE-33.iso.1      PRJEB76547   SAMEA115749413
#
#                                      run_accession  \
# UNIQUEID
# site.11.subj.MDR044.lab.SWE-33.iso.1   ERR13290258
# site.11.subj.MDR044.lab.SWE-33.iso.1   ERR13290259
# site.11.subj.MDR044.lab.SWE-33.iso.1   ERR13290260
# site.11.subj.MDR044.lab.SWE-33.iso.1   ERR13290261
#
#                                                                             center_name  \
# UNIQUEID
# site.11.subj.MDR044.lab.SWE-33.iso.1  University of Oxford;Nuffield Department of Me...
# site.11.subj.MDR044.lab.SWE-33.iso.1  University of Oxford;Nuffield Department of Me...
# site.11.subj.MDR044.lab.SWE-33.iso.1  University of Oxford;Nuffield Department of Me...
# site.11.subj.MDR044.lab.SWE-33.iso.1  University of Oxford;Nuffield Department of Me...
#
#                                      country location first_public  \
# UNIQUEID
# site.11.subj.MDR044.lab.SWE-33.iso.1  Sweden      NaN   2024-06-16
# site.11.subj.MDR044.lab.SWE-33.iso.1  Sweden      NaN   2024-06-16
# site.11.subj.MDR044.lab.SWE-33.iso.1  Sweden      NaN   2024-06-16
# site.11.subj.MDR044.lab.SWE-33.iso.1  Sweden      NaN   2024-06-16
#
#                                                                               fastq_ftp  \
# UNIQUEID
# site.11.subj.MDR044.lab.SWE-33.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR132/058/ERR132...
# site.11.subj.MDR044.lab.SWE-33.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR132/059/ERR132...
# site.11.subj.MDR044.lab.SWE-33.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR132/060/ERR132...
# site.11.subj.MDR044.lab.SWE-33.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR132/061/ERR132...
#
#                                                                               fastq_md5  \
# UNIQUEID
# site.11.subj.MDR044.lab.SWE-33.iso.1  cfc453a1e1df564418db6c7ad5758516;d05e1bfb520d9...
# site.11.subj.MDR044.lab.SWE-33.iso.1  eeeac6640751f602e1a71c9ebb9e13a5;8e7061b9f65c3...
# site.11.subj.MDR044.lab.SWE-33.iso.1  1bc2e8263e96c7477878849d8ee595b0;8a55bf2c2b948...
# site.11.subj.MDR044.lab.SWE-33.iso.1  aeda11e2b6a4684a9b9fc190ee310a89;79b054818723f...
#
#                                               fastq_bytes  has_effects  \
# UNIQUEID
# site.11.subj.MDR044.lab.SWE-33.iso.1  127552558;137373039        False
# site.11.subj.MDR044.lab.SWE-33.iso.1  127552074;137372957        False
# site.11.subj.MDR044.lab.SWE-33.iso.1  127553233;137374103        False
# site.11.subj.MDR044.lab.SWE-33.iso.1  127553222;137374116        False
#
#                                       has_variants  has_mutations  \
# UNIQUEID
# site.11.subj.MDR044.lab.SWE-33.iso.1         False          False
# site.11.subj.MDR044.lab.SWE-33.iso.1         False          False
# site.11.subj.MDR044.lab.SWE-33.iso.1         False          False
# site.11.subj.MDR044.lab.SWE-33.iso.1         False          False
#
#                                       has_predictions  has_main_report  \
# UNIQUEID
# site.11.subj.MDR044.lab.SWE-33.iso.1            False            False
# site.11.subj.MDR044.lab.SWE-33.iso.1            False            False
# site.11.subj.MDR044.lab.SWE-33.iso.1            False            False
# site.11.subj.MDR044.lab.SWE-33.iso.1            False            False
#
#                                       in_mapping_file
# UNIQUEID
# site.11.subj.MDR044.lab.SWE-33.iso.1            False
# site.11.subj.MDR044.lab.SWE-33.iso.1            False
# site.11.subj.MDR044.lab.SWE-33.iso.1            False
# site.11.subj.MDR044.lab.SWE-33.iso.1            False

# %%
lookup.reset_index(inplace=True)

# %%
lookup[['UNIQUEID', 'run_accession']].groupby('UNIQUEID').count().run_accession.value_counts()
# Out:
# run_accession
# 1    44315
# 2      935
# 4      103
# 3       66
# 5        1
# Name: count, dtype: int64

# %%
lookup[lookup.index.duplicated()].index.nunique(), lookup[lookup.index.duplicated(keep=False)].shape
# Out:
# (1105, (2485, 16))

# %%
lookup.to_csv('../data/ENA_EXTRACT_LOOKUP.csv')

# %%
lookup
# Out:
#                                          study_accession sample_accession  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1      PRJEB23245   SAMEA104362043
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1      PRJEB23245   SAMEA104362044
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1      PRJEB23245   SAMEA104362045
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1      PRJEB23245   SAMEA104362046
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1      PRJEB23245   SAMEA104362047
# ...                                                  ...              ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1       PRJNA428596     SAMN08629324
# site.ENA.subj.SAMN03647419.lab.1.iso.1       PRJNA282721     SAMN03647419
# site.ENA.subj.SAMN07766466.lab.1.iso.1       PRJNA413593     SAMN07766466
# site.ENA.subj.SAMN07659660.lab.1.iso.1       PRJNA401515     SAMN07659660
# site.ENA.subj.SAMN08708730.lab.1.iso.1       PRJNA428596     SAMN08708730
#
#                                          run_accession  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1    ERR2184202
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1    ERR2184203
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1    ERR2184204
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1    ERR2184205
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1    ERR2184206
# ...                                                ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1      SRR6797700
# site.ENA.subj.SAMN03647419.lab.1.iso.1      SRR2100246
# site.ENA.subj.SAMN07766466.lab.1.iso.1      SRR6152661
# site.ENA.subj.SAMN07659660.lab.1.iso.1      SRR6045415
# site.ENA.subj.SAMN08708730.lab.1.iso.1      SRR6832238
#
#                                                                                 center_name  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1  University of Oxford;Nuffield Department of Me...
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1  University of Oxford;Nuffield Department of Me...
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1  University of Oxford;Nuffield Department of Me...
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1  University of Oxford;Nuffield Department of Me...
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1  University of Oxford;Nuffield Department of Me...
# ...                                                                                     ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1                                           SUB3743403
# site.ENA.subj.SAMN03647419.lab.1.iso.1                                                  NaN
# site.ENA.subj.SAMN07766466.lab.1.iso.1                                                  NaN
# site.ENA.subj.SAMN07659660.lab.1.iso.1                                                  NaN
# site.ENA.subj.SAMN08708730.lab.1.iso.1                                           SUB3783172
#
#                                                            country  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1                       NaN
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1                       NaN
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1                       NaN
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1                       NaN
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1                       NaN
# ...                                                            ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1                     missing
# site.ENA.subj.SAMN03647419.lab.1.iso.1                     missing
# site.ENA.subj.SAMN07766466.lab.1.iso.1    Canada: British Columbia
# site.ENA.subj.SAMN07659660.lab.1.iso.1      United Kingdom: Oxford
# site.ENA.subj.SAMN08708730.lab.1.iso.1                     missing
#
#                                                  location first_public  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1              NaN   2019-06-12
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1              NaN   2019-06-12
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1              NaN   2019-06-12
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1              NaN   2019-06-12
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1              NaN   2019-06-12
# ...                                                   ...          ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1                NaN   2018-03-03
# site.ENA.subj.SAMN03647419.lab.1.iso.1                NaN   2015-11-03
# site.ENA.subj.SAMN07766466.lab.1.iso.1    49.15 N 123.7 W   2017-10-11
# site.ENA.subj.SAMN07659660.lab.1.iso.1                NaN   2017-12-01
# site.ENA.subj.SAMN08708730.lab.1.iso.1                NaN   2018-03-15
#
#                                                                                   fastq_ftp  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR218/002/ERR218...
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR218/003/ERR218...
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR218/004/ERR218...
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR218/005/ERR218...
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR218/006/ERR218...
# ...                                                                                     ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1    ftp.sra.ebi.ac.uk/vol1/fastq/SRR679/000/SRR679...
# site.ENA.subj.SAMN03647419.lab.1.iso.1    ftp.sra.ebi.ac.uk/vol1/fastq/SRR210/006/SRR210...
# site.ENA.subj.SAMN07766466.lab.1.iso.1    ftp.sra.ebi.ac.uk/vol1/fastq/SRR615/001/SRR615...
# site.ENA.subj.SAMN07659660.lab.1.iso.1    ftp.sra.ebi.ac.uk/vol1/fastq/SRR604/005/SRR604...
# site.ENA.subj.SAMN08708730.lab.1.iso.1    ftp.sra.ebi.ac.uk/vol1/fastq/SRR683/008/SRR683...
#
#                                                                                   fastq_md5  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1  612e42126398723aa1ee84dd1e06feec;349b4db6faead...
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1  469becc8e8fb3961bde32b5352858190;b13aca3a9005c...
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1  d97d6b0ae3ba59f6bfa19e304ac8d94f;022a232fe2db3...
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1  14c0e32a4b0bc1cf763a9d303c9e5ac0;45fc98858531f...
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1  13b208c2682162b7c43eff826e30a8c3;d38eebc5d32fd...
# ...                                                                                     ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1    bc924b9f084012d606433511bef0d18f;ca1f09a5d91f4...
# site.ENA.subj.SAMN03647419.lab.1.iso.1    91a4f700ec3b8a90edcb053dfefa13ad;105ff45492880...
# site.ENA.subj.SAMN07766466.lab.1.iso.1    6b6a27fbc68b9cdaa22a546c4378877a;29023ba0ad61b...
# site.ENA.subj.SAMN07659660.lab.1.iso.1    ed1a023558e8ba5e8f8365c4653c9ff6;a62e326689701...
# site.ENA.subj.SAMN08708730.lab.1.iso.1    3a728e1397b49458d4f709ec2d90fc5e;c8e136513d3e5...
#
#                                                          fastq_bytes  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1          79400918;105468452
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1           67987132;86536083
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1           57530779;72231695
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1           69943262;91063623
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1           69636113;88268311
# ...                                                              ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1    238157;159575999;160379837
# site.ENA.subj.SAMN03647419.lab.1.iso.1           177028172;177053910
# site.ENA.subj.SAMN07766466.lab.1.iso.1           194848851;192505193
# site.ENA.subj.SAMN07659660.lab.1.iso.1           132755503;156882560
# site.ENA.subj.SAMN08708730.lab.1.iso.1      440545;77020083;86536488
#
#                                           has_effects  has_variants  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1        False         False
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1        False         False
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1        False         False
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1        False         False
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1        False         False
# ...                                               ...           ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1          False         False
# site.ENA.subj.SAMN03647419.lab.1.iso.1          False         False
# site.ENA.subj.SAMN07766466.lab.1.iso.1          False         False
# site.ENA.subj.SAMN07659660.lab.1.iso.1          False         False
# site.ENA.subj.SAMN08708730.lab.1.iso.1          False         False
#
#                                           has_mutations  has_predictions  \
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1          False            False
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1          False            False
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1          False            False
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1          False            False
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1          False            False
# ...                                                 ...              ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1            False            False
# site.ENA.subj.SAMN03647419.lab.1.iso.1            False            False
# site.ENA.subj.SAMN07766466.lab.1.iso.1            False            False
# site.ENA.subj.SAMN07659660.lab.1.iso.1            False            False
# site.ENA.subj.SAMN08708730.lab.1.iso.1            False            False
#
#                                           has_main_report  in_mapping_file
# UNIQUEID
# site.05.subj.PTAN-0001.lab.TAN-001.iso.1            False            False
# site.05.subj.PTAN-0002.lab.TAN-004.iso.1            False            False
# site.05.subj.PTAN-0003.lab.TAN-006.iso.1            False            False
# site.05.subj.PTAN-0004.lab.TAN-007.iso.1            False            False
# site.05.subj.PTAN-0005.lab.TAN-010.iso.1            False            False
# ...                                                   ...              ...
# site.ENA.subj.SAMN08629324.lab.1.iso.1              False            False
# site.ENA.subj.SAMN03647419.lab.1.iso.1              False            False
# site.ENA.subj.SAMN07766466.lab.1.iso.1              False            False
# site.ENA.subj.SAMN07659660.lab.1.iso.1              False            False
# site.ENA.subj.SAMN08708730.lab.1.iso.1              False            False
#
# [46800 rows x 16 columns]

# %%
lookup.index.nunique()
# Out:
# 45420
